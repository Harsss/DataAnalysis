# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['Harsh','Sarthak','bindal','akshay'],
    "marks":[97,67,57,57],
    "city":['Shamli','Lucknow','Meerut','Paryagraj']
    
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks       city
# 0    Harsh     97     Shamli
# 1  Sarthak     67    Lucknow
# 2   bindal     57     Meerut
# 3   akshay     57  Paryagraj

# %% [markdown]
# 0,1,2,3 are the index which is used by pandas to identify rows

# %%
df.to_csv('First.csv') 

#To export this dataframe to excel(name or say format as csv) with the name first.csv

# %% [markdown]
# ### To remove this index from our view I can use index argument and make it false

# %%
# df.to_csv('BinaIndexKe.csv',index=False)

# %%
df.head()
# Out:
#       name  marks       city
# 0    Harsh     97     Shamli
# 1  Sarthak     67    Lucknow
# 2   bindal     57     Meerut
# 3   akshay     57  Paryagraj

# %%
df.head(2)
# Out:
#       name  marks     city
# 0    Harsh     97   Shamli
# 1  Sarthak     67  Lucknow

# %%
df.tail(2)
# Out:
#      name  marks       city
# 2  bindal     57     Meerut
# 3  akshay     57  Paryagraj

# %%
df.describe() # Use to calculate the standard Blah Blah Blah Blah of mathematical columns
# Out:
#            marks
# count   4.000000
# mean   69.500000
# std    18.929694
# min    57.000000
# 25%    57.000000
# 50%    62.000000
# 75%    74.500000
# max    97.000000

# %%
nw=pd.read_csv('pdRandom.csv')

# %%
nw
# Out:
#     RollNo  Marks         City
# 0        7     89    Paryagraj
# 1       34     54         Agra
# 2       31     65       Shamli
# 3       23      2   Vaishodevi
# 4      333     32    Badrinath
# 5       12     65    Kedarnath
# 6       76     65     Gangotri
# 7        5    345     Yamnotri
# 8     1243     34  Rameshwaram
# 9        2     34      Banaras
# 10       4     42     Mirzapur

# %%
nw['City']
# Out:
# 0       Paryagraj
# 1            Agra
# 2          Shamli
# 3      Vaishodevi
# 4       Badrinath
# 5       Kedarnath
# 6        Gangotri
# 7        Yamnotri
# 8     Rameshwaram
# 9         Banaras
# 10       Mirzapur
# Name: City, dtype: object

# %%
nw.head()
# Out:
#    RollNo  Marks        City
# 0       7     89   Paryagraj
# 1      34     54        Agra
# 2      31     65      Shamli
# 3      23      2  Vaishodevi
# 4     333     32   Badrinath

# %% [markdown]
# ### To view or say target any specific value in the column use jaise niche kiya

# %%
nw['City'][5]
# Out:
# 'Kedarnath'

# %%
# To change
nw['City']
# Out:
# 0       Paryagraj
# 1            Agra
# 2          Shamli
# 3      Vaishodevi
# 4       Badrinath
# 5       Kedarnath
# 6        Gangotri
# 7        Yamnotri
# 8     Rameshwaram
# 9         Banaras
# 10       Mirzapur
# Name: City, dtype: object

# %%
nw['City'][1]="Delhi"
# Out:
# c:\users\ssc\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
nw['City']
# Out:
# 0       Paryagraj
# 1           Delhi
# 2          Shamli
# 3      Vaishodevi
# 4       Badrinath
# 5       Kedarnath
# 6        Gangotri
# 7        Yamnotri
# 8     Rameshwaram
# 9         Banaras
# 10       Mirzapur
# Name: City, dtype: object

# %%
nw
# Out:
#     RollNo  Marks         City
# 0        7     89    Paryagraj
# 1       34     54        Delhi
# 2       31     65       Shamli
# 3       23      2   Vaishodevi
# 4      333     32    Badrinath
# 5       12     65    Kedarnath
# 6       76     65     Gangotri
# 7        5    345     Yamnotri
# 8     1243     34  Rameshwaram
# 9        2     34      Banaras
# 10       4     42     Mirzapur

# %% [markdown]
# ### getting bore from this 0,1,2 .. index lets change it

# %%
nw.index=['a','b','c','d','e','f','g','h','i','j','k']

# %%
type(nw)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## this is the over view of pandas so lets just see some more operations just a bit more

# %%
PdSer=pd.Series(np.random.rand(50))

# %%
PdSer
# Out:
# 0     0.901130
# 1     0.391275
# 2     0.249380
# 3     0.035074
# 4     0.191077
# 5     0.049148
# 6     0.855226
# 7     0.752040
# 8     0.864790
# 9     0.661090
# 10    0.900672
# 11    0.144747
# 12    0.208971
# 13    0.360652
# 14    0.246858
# 15    0.257533
# 16    0.776108
# 17    0.338435
# 18    0.059014
# 19    0.530058
# 20    0.575450
# 21    0.663845
# 22    0.400277
# 23    0.042591
# 24    0.204148
# 25    0.087764
# 26    0.608190
# 27    0.705985
# 28    0.387000
# 29    0.810699
# 30    0.061167
# 31    0.626036
# 32    0.959486
# 33    0.612545
# 34    0.524012
# 35    0.754280
# 36    0.789048
# 37    0.150067
# 38    0.733508
# 39    0.275806
# 40    0.749996
# 41    0.423285
# 42    0.232218
# 43    0.580559
# 44    0.166558
# 45    0.799304
# 46    0.207054
# 47    0.817324
# 48    0.262678
# 49    0.871576
# dtype: float64

# %%
# This is a series(a 1d dataframe is known as series)

# %%
df=pd.DataFrame(np.random.rand(200,5))

# %%
df
# Out:
#             0         1         2         3         4
# 0    0.792942  0.380704  0.029556  0.593512  0.830615
# 1    0.206925  0.632565  0.557874  0.932799  0.364357
# 2    0.946665  0.834942  0.390186  0.280231  0.956991
# 3    0.100888  0.857076  0.618211  0.189216  0.025525
# 4    0.554606  0.770915  0.517224  0.998280  0.509732
# ..        ...       ...       ...       ...       ...
# 195  0.463545  0.540865  0.753857  0.888182  0.085887
# 196  0.289073  0.772528  0.952003  0.311977  0.215072
# 197  0.928429  0.388160  0.118165  0.720212  0.305541
# 198  0.327536  0.730506  0.702829  0.784336  0.511507
# 199  0.891521  0.450798  0.801731  0.796161  0.428510
#
# [200 rows x 5 columns]

# %%
df.describe()
# Out:
#                 0           1           2           3           4
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.498223    0.532510    0.494024    0.506317    0.496479
# std      0.289688    0.273597    0.276765    0.276691    0.275660
# min      0.000124    0.000461    0.003982    0.000559    0.005249
# 25%      0.272756    0.317601    0.264662    0.282927    0.269767
# 50%      0.521903    0.533960    0.463884    0.510335    0.494418
# 75%      0.720050    0.771318    0.735013    0.735573    0.742873
# max      0.993821    0.997822    0.989422    0.998280    0.998481

# %%
df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %% [markdown]
# ## Bhaisaab ab ek dikkat hogi hme numpy array ke saath khelna to aata h lekin dataframe to ek dum hi nayi chiz h ab kya karoo

# %%
# Lets Change our df to array

DftoNp=df.to_numpy()

# %%
DftoNp
# Out:
# array([[7.92941636e-01, 3.80703786e-01, 2.95560882e-02, 5.93511506e-01,
#         8.30615088e-01],
#        [2.06924983e-01, 6.32565270e-01, 5.57874308e-01, 9.32798718e-01,
#         3.64357237e-01],
#        [9.46665121e-01, 8.34942407e-01, 3.90185831e-01, 2.80230560e-01,
#         9.56990617e-01],
#        [1.00887722e-01, 8.57075593e-01, 6.18211292e-01, 1.89215669e-01,
#         2.55254858e-02],
#        [5.54606129e-01, 7.70914755e-01, 5.17223532e-01, 9.98279938e-01,
#         5.09731790e-01],
#        [1.21235827e-01, 9.96877205e-01, 5.79955572e-01, 1.62113330e-01,
#         2.11235306e-01],
#        [2.85436718e-01, 6.31713643e-01, 5.73935610e-01, 2.08741938e-03,
#         8.33680306e-01],
#        [1.00642130e-01, 8.84606510e-01, 1.99984950e-01, 6.53102274e-02,
#         4.81730930e-01],
#        [3.58645647e-01, 4.53175613e-01, 4.47842789e-01, 5.11435340e-01,
#         3.50388495e-02],
#        [9.90801746e-01, 4.03405672e-01, 9.38427130e-01, 8.76053181e-01,
# ...

# %%
df.head()
# Out:
#           0         1         2         3         4
# 0  0.792942  0.380704  0.029556  0.593512  0.830615
# 1  0.206925  0.632565  0.557874  0.932799  0.364357
# 2  0.946665  0.834942  0.390186  0.280231  0.956991
# 3  0.100888  0.857076  0.618211  0.189216  0.025525
# 4  0.554606  0.770915  0.517224  0.998280  0.509732

# %%
# Sorting on the axis we use the sort function

df.sort_index(axis=1, ascending=False)
# Out:
#             4         3         2         1         0
# 0    0.830615  0.593512  0.029556  0.380704  0.792942
# 1    0.364357  0.932799  0.557874  0.632565  0.206925
# 2    0.956991  0.280231  0.390186  0.834942  0.946665
# 3    0.025525  0.189216  0.618211  0.857076  0.100888
# 4    0.509732  0.998280  0.517224  0.770915  0.554606
# ..        ...       ...       ...       ...       ...
# 195  0.085887  0.888182  0.753857  0.540865  0.463545
# 196  0.215072  0.311977  0.952003  0.772528  0.289073
# 197  0.305541  0.720212  0.118165  0.388160  0.928429
# 198  0.511507  0.784336  0.702829  0.730506  0.327536
# 199  0.428510  0.796161  0.801731  0.450798  0.891521
#
# [200 rows x 5 columns]

# %%
newdf=df # This made a view or say pointer

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.792942  0.380704  0.029556  0.593512  0.830615
# 1  0.206925  0.632565  0.557874  0.932799  0.364357
# 2  0.946665  0.834942  0.390186  0.280231  0.956991
# 3  0.100888  0.857076  0.618211  0.189216  0.025525
# 4  0.554606  0.770915  0.517224  0.998280  0.509732

# %%
newdf[0][0]=9

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  9.000000  0.380704  0.029556  0.593512  0.830615
# 1  0.206925  0.632565  0.557874  0.932799  0.364357
# 2  0.946665  0.834942  0.390186  0.280231  0.956991
# 3  0.100888  0.857076  0.618211  0.189216  0.025525
# 4  0.554606  0.770915  0.517224  0.998280  0.509732

# %%
df.head()
# Out:
#           0         1         2         3         4
# 0  9.000000  0.380704  0.029556  0.593512  0.830615
# 1  0.206925  0.632565  0.557874  0.932799  0.364357
# 2  0.946665  0.834942  0.390186  0.280231  0.956991
# 3  0.100888  0.857076  0.618211  0.189216  0.025525
# 4  0.554606  0.770915  0.517224  0.998280  0.509732

# %%
newdf2=df.copy()  # This made a copy

# %%
df.head()
# Out:
#           0         1         2         3         4
# 0  9.000000  0.380704  0.029556  0.593512  0.830615
# 1  0.206925  0.632565  0.557874  0.932799  0.364357
# 2  0.946665  0.834942  0.390186  0.280231  0.956991
# 3  0.100888  0.857076  0.618211  0.189216  0.025525
# 4  0.554606  0.770915  0.517224  0.998280  0.509732

# %%
# To mantain this copy and view problem we always used loc function and not that rough setting

# %%
df.loc[0,1]=20

# %%
df.head()
# Out:
#           0          1         2         3         4
# 0  9.000000  20.000000  0.029556  0.593512  0.830615
# 1  0.206925   0.632565  0.557874  0.932799  0.364357
# 2  0.946665   0.834942  0.390186  0.280231  0.956991
# 3  0.100888   0.857076  0.618211  0.189216  0.025525
# 4  0.554606   0.770915  0.517224  0.998280  0.509732

# %%
df.drop(1, axis=0)  #If we dont give the axis so it take 0 as the default
# Out:
#             0          1         2         3         4
# 0    9.000000  20.000000  0.029556  0.593512  0.830615
# 2    0.946665   0.834942  0.390186  0.280231  0.956991
# 3    0.100888   0.857076  0.618211  0.189216  0.025525
# 4    0.554606   0.770915  0.517224  0.998280  0.509732
# 5    0.121236   0.996877  0.579956  0.162113  0.211235
# ..        ...        ...       ...       ...       ...
# 195  0.463545   0.540865  0.753857  0.888182  0.085887
# 196  0.289073   0.772528  0.952003  0.311977  0.215072
# 197  0.928429   0.388160  0.118165  0.720212  0.305541
# 198  0.327536   0.730506  0.702829  0.784336  0.511507
# 199  0.891521   0.450798  0.801731  0.796161  0.428510
#
# [199 rows x 5 columns]

# %%
df.loc[(df[0]>0.9)] # To rum queries in pandas and for and we can use &
# Out:
#             0          1         2         3         4
# 0    9.000000  20.000000  0.029556  0.593512  0.830615
# 2    0.946665   0.834942  0.390186  0.280231  0.956991
# 9    0.990802   0.403406  0.938427  0.876053  0.391383
# 29   0.964415   0.013863  0.112363  0.543011  0.393718
# 42   0.901817   0.139464  0.989422  0.599695  0.806194
# 54   0.951654   0.705871  0.281778  0.584717  0.035187
# 69   0.938591   0.443080  0.426825  0.091314  0.432969
# 70   0.993821   0.887571  0.987842  0.809340  0.225770
# 80   0.949264   0.942451  0.142100  0.526396  0.801717
# 84   0.913526   0.630446  0.375437  0.856136  0.845480
# 92   0.978266   0.062708  0.405353  0.899076  0.886524
# 95   0.946610   0.536008  0.145157  0.892132  0.396813
# 100  0.943092   0.338693  0.080048  0.373792  0.339592
# 118  0.983129   0.679771  0.441356  0.283826  0.810784
# 140  0.984607   0.967585  0.165164  0.800475  0.216563
# 155  0.914312   0.617371  0.348903  0.598608  0.729713
# ...

# %%
df.head()
# Out:
#           0          1         2         3         4
# 0  9.000000  20.000000  0.029556  0.593512  0.830615
# 1  0.206925   0.632565  0.557874  0.932799  0.364357
# 2  0.946665   0.834942  0.390186  0.280231  0.956991
# 3  0.100888   0.857076  0.618211  0.189216  0.025525
# 4  0.554606   0.770915  0.517224  0.998280  0.509732

# %% [markdown]
# ## If  we need to count then use iloc and if we need to target then we must use the loc

# %% [markdown]
# ### Let me rephrase myself
#
# # yadi mujhe column and rows ko ginte target karna h to iloc istemar hoga or yadi index ke naam se karna h to loc

# %%
df.head()
# Out:
#           0          1         2         3         4
# 0  9.000000  20.000000  0.029556  0.593512  0.830615
# 1  0.206925   0.632565  0.557874  0.932799  0.364357
# 2  0.946665   0.834942  0.390186  0.280231  0.956991
# 3  0.100888   0.857076  0.618211  0.189216  0.025525
# 4  0.554606   0.770915  0.517224  0.998280  0.509732

# %%
df.columns=list("ABCDE")

# %%
df.head()
# Out:
#           A          B         C         D         E
# 0  9.000000  20.000000  0.029556  0.593512  0.830615
# 1  0.206925   0.632565  0.557874  0.932799  0.364357
# 2  0.946665   0.834942  0.390186  0.280231  0.956991
# 3  0.100888   0.857076  0.618211  0.189216  0.025525
# 4  0.554606   0.770915  0.517224  0.998280  0.509732

# %%
df.iloc[2,3]
# Out:
# 0.28023055957616216

# %%
type(df.iloc[2,:])
# Out:
# pandas.core.series.Series

# %%
type(df.iloc[2,3])
# Out:
# numpy.float64

# %%
df.loc[2,'A']
# Out:
# 0.9466651209338007
